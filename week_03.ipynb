# %%
print('hello world!')
# Out:
# hello world!

# %%
#100분은 몇 시간 몇 분인지 출력해 보세요.
print('100 분은', 100//60, '시간', 100%60, '분 입니다.')
# Out:
# 100 분은 1 시간 40 분 입니다.

# %%
#100분은 몇 시간 몇 분인지 출력해 보세요.
time = 100
print(time, '분은 ', time//60, '시간', time%60, '분 입니다.')
# Out:
# 100 분은  1 시간 40 분 입니다.

# %%
#(사용자 입력)분은 몇 시간 몇 분인지 출력해 보세요. 

time = int(input('분을 입력하세요'))
print(time, '분은 ', time//60, '시간', time%60, '분 입니다.')
# Out:
# 분을 입력하세요 100
# 100 분은  1 시간 40 분 입니다.

# %%
#(사용자 입력)분은 몇 시간 몇 분인지 출력해 보세요. 

time = int(input('분을 입력하세요'))
print(f'{time}분은 {time//60}시간 {time%60}분 입니다.')
# Out:
# 분을 입력하세요 120
# 120분은 2시간 0분 입니다.

# %%
a = 10
a += 7
print(a)
# Out:
# 17

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name = input('이름을 입력하세요.')
age = int(input('나이를 입력하세요.'))
print(name, age)
print(type(age))
age=age+2
print(age)
# Out:
# 이름을 입력하세요. 정아린
# 나이를 입력하세요. 21
# 정아린 21
# <class 'int'>
# 23

# %%
#숫자를 입력받아서 짝수인지 홀수인지 출력하는 프로그램을 작성하시오.

num = int(input('숫자를 입력하세요.'))
if (num % 2 == 0):
    print(f'{num}은 짝수입니다.') 
else:
    print(f'{num}은 홀수입니다.')
# Out:
# 숫자를 입력하세요. 129
# 129은 홀수입니다.
